# %%
# import libraries
import os
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import numpy as np
import warnings
warnings.filterwarnings('ignore')
np.random.seed(0)

# %% [markdown]
# #Mount the google drive for importing a dataset of catalog.data.gov

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Loading the dataset in pandas dataframe

# %%
df_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2006_-_2011_NYS_Math_Test_Results_by_Grade_-_Citywide_-_by_Race-Ethnicity.csv')

# %%
df_raw.head(10)
# Out:
#         Grade  Year Category  ...  Level 4 %  Level 3+4 #  Level 3+4 %
# 0           3  2006    Asian  ...       49.7         8982         92.0
# 1           4  2006    Asian  ...       48.5         9079         91.0
# 2           5  2006    Asian  ...       42.6         8576         87.0
# 3           6  2006    Asian  ...       34.7         7978         83.1
# 4           7  2006    Asian  ...       26.8         7214         76.5
# 5           8  2006    Asian  ...       27.9         7075         73.8
# 6  All Grades  2006    Asian  ...       38.5        48904         84.0
# 7           3  2007    Asian  ...       54.4         9192         94.3
# 8           4  2007    Asian  ...       52.0         9108         92.2
# 9           5  2007    Asian  ...       49.6         9274         91.7
#
# [10 rows x 15 columns]

# %% [markdown]
# #The name of each column in a sorted order

# %%
print(sorted(df_raw))
# Out:
# ['Category', 'Grade', 'Level 1 #', 'Level 1 %', 'Level 2 #', 'Level 2 %', 'Level 3 #', 'Level 3 %', 'Level 3+4 #', 'Level 3+4 %', 'Level 4 #', 'Level 4 %', 'Mean Scale Score', 'Number Tested', 'Year']

# %% [markdown]
# #The total number of rows in a dataset

# %%
df_raw.shape

# In the dataset, we have total 168 rows and 15 columns
# Out:
# (168, 15)

# %% [markdown]
# #Add a new column computed from already existing columns in a dataframe

# %%
df_raw['Level 1+2 #'] = df_raw['Level 1 #'] + df_raw['Level 2 #']
df_raw['Level 1+2 %'] = df_raw['Level 1 %'] + df_raw['Level 2 %']

df_raw.head(20)
# Out:
#          Grade  Year Category  ...  Level 3+4 %  Level 1+2 #  Level 1+2 %
# 0            3  2006    Asian  ...         92.0          786          8.1
# 1            4  2006    Asian  ...         91.0          894          8.9
# 2            5  2006    Asian  ...         87.0         1276         12.9
# 3            6  2006    Asian  ...         83.1         1628         16.9
# 4            7  2006    Asian  ...         76.5         2219         23.5
# 5            8  2006    Asian  ...         73.8         2518         26.3
# 6   All Grades  2006    Asian  ...         84.0         9321         16.0
# 7            3  2007    Asian  ...         94.3          558          5.7
# 8            4  2007    Asian  ...         92.2          773          7.8
# 9            5  2007    Asian  ...         91.7          837          8.3
# 10           6  2007    Asian  ...         88.6         1121         11.4
# 11           7  2007    Asian  ...         84.1         1553         15.9
# ...

# %% [markdown]
# #Save the results to local csv

# %%
df_raw.to_csv('/content/drive/MyDrive/Colab Notebooks/result1.csv')
